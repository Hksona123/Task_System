# %%
from google.colab import files
uploaded=files.upload()
# !rm -rf /root/nltk_data/tokenizers/punkt
# Out:
#      <input type="file" id="files-198404fc-eabf-409e-82b6-9939b261aa43" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-198404fc-eabf-409e-82b6-9939b261aa43">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Install & import required libraries
import pandas as pd
import nltk
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Download required NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
import spacy
nlp = spacy.load("en_core_web_sm")

def tokenize_text(text):
    doc = nlp(text)
    return [token.text for token in doc if not token.is_space]

# Test it
test_text = "Hello! This is a test for spaCy tokenization."
tokens = tokenize_text(test_text)
print(tokens)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 60.8 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# ['Hello', '!', 'This', 'is', 'a', 'test', 'for', 'spaCy', 'tokenization', '.']

# %%
# ✅ 3. Load CSV into DataFrame
df = pd.read_csv("Smart_Todo_App.csv")  # make sure name matches uploaded file
df.head()
# Out:
#                 Task Description Category        Skill
# 0  Implement user authentication  backend  spring boot
# 1    Optimize server performance  backend      asp.net
# 2     Manage database operations  backend       django
# 3  Implement user authentication  backend          api
# 4           Build a microservice  backend       kotlin

# %%
# ✅ 4. View column names & check for nulls
print(df.columns.tolist())
print("\nMissing values:\n")
print(df.isnull().sum())
# Out:
# ['Task Description', 'Category', 'Skill']
#
# Missing values:
#
# Task Description    0
# Category            0
# Skill               0
# dtype: int64

# %%
# ✅ 5. Rename column if needed (e.g., 'Task Description' → 'description')
df.rename(columns={'Task Description': 'description'}, inplace=True)
df = df.dropna(subset=['description'])
df.reset_index(drop=True, inplace=True)

# %%
# ✅ 6. Define preprocessing function
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# from nltk.tokenize.punkt import PunktTokenizer # Remove explicit import

# Initialize the Punkt tokenizer for English
# punkt_tokenizer = PunktTokenizer('english') # Remove explicit initialization

def preprocess_text(text):
    # Lowercase
    text = text.lower()
    # Tokenize using word_tokenize
    tokens = word_tokenize(text) # Use word_tokenize directly
    # Remove punctuation and stopwords, and lemmatize
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word.isalpha() and word not in stop_words]
    return ' '.join(tokens)

# %%
# ✅ 7. Apply preprocessing to description column
import pandas as pd
import re

# Sample stopwords list (can be expanded)
stopwords = set([
    'the', 'is', 'in', 'it', 'of', 'and', 'a', 'to', 'for', 'on', 'with',
    'this', 'that', 'as', 'an', 'be', 'are', 'was', 'at', 'by', 'or'
])

# Simple preprocess function without nltk
def preprocess_text(text):
    if pd.isnull(text):
        return ""

    # 1. Lowercase
    text = text.lower()

    # 2. Remove non-alphabet characters
    text = re.sub(r'[^a-z\s]', '', text)

    # 3. Tokenize using split
    tokens = text.split()

    # 4. Remove stopwords
    tokens = [word for word in tokens if word not in stopwords]

    return " ".join(tokens)

# Apply preprocessing to 'description' column
df['cleaned_text'] = df['description'].apply(preprocess_text)

# Show result
df.head()
# Out:
#                      description  ...                   cleaned_text
# 0  Implement user authentication  ...  implement user authentication
# 1    Optimize server performance  ...    optimize server performance
# 2     Manage database operations  ...     manage database operations
# 3  Implement user authentication  ...  implement user authentication
# 4           Build a microservice  ...             build microservice
#
# [5 rows x 4 columns]

# %%
# ✅ 8. Save cleaned data to new CSV
df.to_csv("Cleaned_Smart_Todo.csv", index=False)

# Optional: Download to local machine
files.download("Cleaned_Smart_Todo.csv")
